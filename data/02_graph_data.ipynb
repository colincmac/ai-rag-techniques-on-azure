# %%
# First copy the .env.example file to .env and fill in the values
import os
import sys
from dotenv import load_dotenv

notebook_dir = os.path.abspath("")
parent_dir = os.path.dirname(notebook_dir)
grandparent_dir = os.path.dirname(parent_dir)


sys.path.append(grandparent_dir)
load_dotenv()
# Out:
# True

# %%
# from glob import glob
# import json
# json_files = glob("_test_assets\\basic_info\\*.json")
# for json_file in json_files:
#     with open(json_file, "r+") as f:
#         data = json.load(f)
#         if 'cusips' in data:
#             value = data['cusips']
#             if isinstance(value, list):
#                 continue
#             elif isinstance(value, float):
#                 value = []
#             else:
#                 value = value.split(",")
#             data["cusips"] = value
#         else:
#             data["cusips"] = []
#         f.seek(0)
#         json.dump(data, f, indent=4)
#         f.truncate()

# %%
from typing import Any, Dict, List, NamedTuple, Union
from promptflow.connections import CustomStrongTypeConnection
from promptflow.contracts.types import Secret
from promptflow.core import ToolProvider
from langchain_community.graphs.graph_document import GraphDocument, Node, Relationship
from langchain_community.graphs.graph_store import GraphStore
import networkx as nx
import sys
class CosmosConnection(CustomStrongTypeConnection):
    """My custom strong type connection.

    :param api_key: The api key.
    :type api_key: Secret
    :param api_base: The api base.
    :type api_base: String
    """
    endpoint: str # wss://<YOUR_ENDPOINT>.gremlin.cosmos.azure.com:443/
    traversal_source: str = "g"
    username: str # /dbs/<YOUR_DATABASE>/colls/<YOUR_COLLECTION_OR_GRAPH>
    access_key: Secret


class KnowledgeTriple(NamedTuple):
    """Knowledge triple in the graph."""

    subject: str
    predicate: str
    object_: str

    @classmethod
    def from_string(cls, triple_string: str) -> "KnowledgeTriple":
        """Create a KnowledgeTriple from a string."""
        subject, predicate, object_ = triple_string.strip().split(", ")
        subject = subject[1:]
        object_ = object_[:-1]
        return cls(subject, predicate, object_)

def parse_triples(knowledge_str: str, triple_delimiter: str = "<|>") -> List[KnowledgeTriple]:
    """Parse knowledge triples from the knowledge string."""
    knowledge_str = knowledge_str.strip()
    if not knowledge_str or knowledge_str == "NONE":
        return []
    triple_strs = knowledge_str.split(triple_delimiter)
    results = []
    for triple_str in triple_strs:
        try:
            kg_triple = KnowledgeTriple.from_string(triple_str)
        except ValueError:
            continue
        results.append(kg_triple)
    return results


def get_entities(entity_str: str) -> List[str]:
    """Extract entities from entity string."""
    if entity_str.strip() == "NONE":
        return []
    else:
        return [w.strip() for w in entity_str.split(",")]

    
# https://github.com/langchain-ai/langchain/blob/master/libs/community/langchain_community/graphs/gremlin_graph.py
class CosmosDBGraphStore(ToolProvider):
    @property
    def get_structured_schema(self) -> Dict[str, Any]:
        return self.structured_schema
    
    def __init__(self, connection: CosmosConnection):
        super().__init__()
        try:
            import asyncio
            import async_timeout
            from gremlin_python.driver import client, serializer
            if sys.platform == "win32":
                asyncio.set_event_loop_policy(asyncio.WindowsSelectorEventLoopPolicy())
        except ImportError:
            raise ImportError(
                "Please install gremlin-python, asyncio, and async_timeout first: " "`pip3 install gremlinpython"
            )
        self.connection = connection
        self.client = client.Client(
            url=connection.endpoint,
            traversal_source=connection.traversal_source,
            username=connection.username,
            password=connection.access_key,
            message_serializer=serializer.GraphSONSerializersV2d0(),

        )
        self.schema: str = ""
        self.nxGraph: nx.Graph = nx.Graph()

    def refresh_schema(self) -> None:
        """
        Refreshes the Gremlin graph schema information.
        """
        vertex_schema = self.client.submit("g.V().label().dedup()").all().result()
        edge_schema = self.client.submit("g.E().label().dedup()").all().result()
        vertex_properties = (
            self.client.submit(
                "g.V().group().by(label).by(properties().label().dedup().fold())"
            )
            .all()
            .result()[0]
        )

        self.structured_schema = {
            "vertex_labels": vertex_schema,
            "edge_labels": edge_schema,
            "vertice_props": vertex_properties,
        }

        self.schema = "\n".join(
            [
                "Vertex labels are the following:",
                ",".join(vertex_schema),
                "Edge labes are the following:",
                ",".join(edge_schema),
                f"Vertices have following properties:\n{vertex_properties}",
            ]
        )
    
    def refresh_nx_graph(self) -> nx.Graph:
        """
        Returns the graph as a NetworkX graph.
        """
        vertices = self.client.submit("g.V().valueMap()").all().result()
        edges = self.client.submit("g.E().valueMap()").all().result()
        for vertex in vertices:
            self.nxGraph.add_node(vertex["id"], **vertex)
        for edge in edges:
            self.nxGraph.add_edge(edge["outV"], edge["inV"], **edge)
            
        return self.nxGraph
    
    def query(self, query: str, params: dict = {}) -> List[Dict[str, Any]]:
        q = self.client.submit(query)
        return q.all().result()
    
    # Upsert could be done by mergev instead, but 3.6 version that supports the operator isn't recommended by Cosmos
    def build_vertex_query(self, node: Node, base_traversal: str = "g.") -> str:
        base_query = (
            f"{base_traversal}V().has('id','{node.id}').fold()"
            + f".coalesce(unfold(),addV('{node.type}')"
            + f".property('id','{node.id}')"
            + f".property('type','{node.type}')"
        )
        for key, value in node.properties.items():
            if(key == "description" or key == "text_unit_ids" or key == "document_ids" or key == "community_ids"):
                base_query += f".property(list, '{key}', '{value}')"
            if(isinstance(value, list)):
                for val in value:
                    base_query += f".property(list, '{key}', '{val}')"
            if(isinstance(value, list)):
                for val in value:
                    base_query += f".property(list, '{key}', '{val}')"
            else:
                base_query += f".property('{key}', '{value}')"
        print(base_query)
        return base_query + ")"
    
    def build_edge_query(self, relationship: Relationship) -> str:
        source_query = f".has('id','{relationship.source.id}')"
        target_query = f".has('id','{relationship.target.id}')"
        base_query = f""""g.V(){source_query}.as('a')  
            .V(){target_query}.as('b') 
            .choose(
                __.inE('{relationship.type}').where(outV().as('a')),
                __.identity(),
                __.addE('{relationship.type}').from('a').to('b')
            )        
            """.replace("\n", "").replace("\t", "")
        
        for key, value in relationship.properties.items():
            if(key == "weight"):
                base_query += f".property('{key}', union(value('weight'), constant({value})).sum())" 
            # edges don't support list properties
            # if(key == "description" or key == "text_unit_ids" or key == "document_ids"):
            #     base_query += f".property(list, '{key}', '{value}')" 
            else:
                base_query += f".property('{key}', '{value}')"
        print(f"edge query: {base_query}")
        return base_query

    def upsert_node(self, node: Node, node_cache: dict = {}) -> Node:
        # if properties does not have label, add type as label
        if "label" not in node.properties:
            node.properties["label"] = node.type
        if node.id in node_cache:
            return node_cache[node.id]
        else:
            query = self.build_vertex_query(node)
            _ = self.client.submit(query).all().result()[0]
            node_cache[node.id] = node
            return node

    def add_edge(self, relationship: Relationship) -> Any:
        query = self.build_edge_query(relationship)
        return self.client.submit(query).all().result()
    
    def add_graph(
        self, graph: nx.Graph, include_source: bool = False
    ) -> None:
        """
        Upsert a NetworkX Graph into a Gremlin Graph DB.
        """
        node_cache: Dict[Union[str, int], Node] = {}
        for node in graph.nodes(data=True):
            self.upsert_node(Node(id=node[0], type=node[1]["type"], properties=node[1]), node_cache)

        
        for edge in graph.edges(data=True):
            source = edge[0]
            target = edge[1]
            self.add_edge(
                Relationship(
                    source=Node(id=source, type=graph.nodes[source]["type"]),
                    target=Node(id=target, type=graph.nodes[target]["type"]),
                    type=edge[2]["type"],
                    properties=edge[2],
                )
            )

# %%
import pandas as pd
import yfinance as yf
from requests import Session
from requests_cache import CacheMixin, SQLiteCache
from requests_ratelimiter import LimiterMixin, MemoryQueueBucket
from pyrate_limiter import Duration, RequestRate, Limiter
from glob import glob
import json
from langchain_community.graphs.graph_document import GraphDocument, Node, Relationship
import nest_asyncio
from utils.text_helpers import clean_text
import hashlib
nest_asyncio.apply()


# From https://www.sec.gov/files/company_tickers.json
sec_ticker_information = json.load(open("_test_assets\\company_tickers_exchange.json"))
graphDbConnection = CosmosConnection(
  configs={
    "endpoint": os.getenv("COSMOS_GRAPH_ENDPOINT"),
    "username": f"/dbs/{os.getenv("COSMOS_GRAPH_DATABASE_NAME")}/colls/{os.getenv('COSMOS_GRAPH_COLLECTION_NAME')}",
    "traversal_source": "g"
  },
  secrets={
    "access_key": os.getenv("COSMOS_GRAPH_ACCESS_KEY")
  }
)

class CachedLimiterSession(CacheMixin, LimiterMixin, Session):
    pass
session = CachedLimiterSession(
    limiter=Limiter(RequestRate(2, Duration.SECOND*5)),  # max 2 requests per 5 seconds
    bucket_class=MemoryQueueBucket,
    backend=SQLiteCache("yfinance.cache"),
)
## Example on how to get financials for a specific company
def get_financials(ticker: str, cik: str, cusips: list[str], session: Session, output_directory: str = "_test_assets\\basic_info"):
    try:
        output_file = f"{output_directory}\\{ticker}_{cik}.json"
        if os.path.exists(output_file):
            return
        stock = yf.Ticker(ticker, session=session)
        info = stock.info
        info['cik'] = cik
        info['cusips'] = cusips
        with open(f"{output_directory}\\{ticker}_{cik}.json", "w") as jsonfile:
            json.dump(info, jsonfile)
        return info
    except Exception as e:
        print(f"Error getting {ticker}: {e}")
        return {}

def upsert_companies(input_directory: str, file_names: List[str] = [], cik_cusip_ticker_csv_file: str = "_test_assets\\sector_communication\\sector_info.csv"):
    graphClient = CosmosDBGraphStore(connection=graphDbConnection)
    files = [f"{input_directory}/{file_name}" for file_name in file_names]
    sector_df = pd.read_csv(cik_cusip_ticker_csv_file)

    for file_json in files:
        with open(file_json, "r") as jsonfile:
            content = json.loads(jsonfile.read())
            print(f"upserting {file_json}")
        #     cusips = []
        #     tickers = []
        #     for cusip_list, ticker_list in sector_df[sector_df['cik'] == content['cik']][['cusips', 'ticker']].values:
        #         if isinstance(cusip_list, str) and cusip_list != "nan":
        #             cusips.extend(cusip_list.split(","))
        #         tickers.append(ticker_list)
        #     node = graphClient.upsert_node(Node(
        #         id=content['entityName'],
        #         type="Company",
        #         properties={
        #         "cik": content.get("cik"),
        #         "tickers": tickers,
        #         "primaryExchange": content.get("primaryExchange", "UNKNOWN"),
        #         "phone": content.get("phone", "UNKNOWN"),
        #         "names": content.get("entityName", "UNKNOWN"),
        #         "partitionKeyType": "primarySector",
        #         "partitionKey": content.get("sector", "UNKNOWN"),
        #         "primarySector": content.get("sector", "UNKNOWN"),
        #         "primaryIndustry": content.get("industry", "UNKNOWN"),
        #         "longBusinessSummary": clean_text(content.get("longBusinessSummary", "UNKNOWN")),
        #         "address1": clean_text(content.get("address1", "UNKNOWN")),
        #         "city": content.get("city", "UNKNOWN"),
        #         "state": content.get("state", "UNKNOWN"),
        #         "zip": content.get("zip", "UNKNOWN"),
        #         "country": content.get("country", "UNKNOWN"),
        #         "cusips": cusips,
        #         }
        # ))
        # upsert_industry(content, graphClient)
        people = []
        for person in content.get("companyOfficers", []):
            people.append(upsert_people(person, content['entityName'], content['sector'], graphClient))
        print(f"upserted {people}")

def upsert_industry(content: dict[str,str], graphClient: CosmosDBGraphStore):
    if content.get("industry") is None:
        return
    result = graphClient.add_edge(Relationship(
        source=Node(id=content['entityName'], type="Company"),
        target=Node(id=content['industry'], 
                    type="Industry", 
                    properties={
                       "partitionKeyType": "sector", 
                       "partitionKey": content['sector'],
                       "sector": content['sector'],
           }),
        type="IN_INDUSTRY",
        
    ))
    return result
def upsert_people(content: dict[str,str], entity_name: str, sector: str, graphClient: CosmosDBGraphStore):
    if content.get("name") is None:
        return
    person_name = clean_text(content['name'])
    person_node = graphClient.upsert_node(Node(
                    id= f"{entity_name}|{person_name}", 
                    type="Person", 
                    properties={
                       "partitionKeyType": "sector",
                       "partitionKey": sector,
                       "sector": sector,
                       "yearBorn": content.get("yearBorn", 0)
           }))
    result = graphClient.add_edge(Relationship(
        source=Node(id=entity_name, type="Company"),
        target=person_node,
        type="HAS_OFFICER",
        properties={
            "title": clean_text(content['title']),
            "fiscalYear": content.get("fiscalYear", 0),
            "totalPay": content.get("totalPay", 0),
            "excersicedValue": content.get("exercisedValue", 0),
            "unexcersicedValue": content.get("unexercisedValue", 0),        
        }
    ))
    return result
sector_df = pd.read_csv("_test_assets\\sector_communication\\sector_info.csv")
## Generate these files through the get_financials function
file_list = [f"{ticker}_{cik}.json" for ticker,cik in sector_df[['ticker', 'cik']].values]
upsert_companies("_test_assets\\basic_info", file_list)
# Out:
# upserting _test_assets\basic_info/GOOGL_1652044.json
# g.V().has('id','Alphabet Inc.|Mr. Sundar  Pichai').fold().coalesce(unfold(),addV('Person').property('id','Alphabet Inc.|Mr. Sundar  Pichai').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1973').property('label', 'Person')
# edge query: "g.V().has('id','Alphabet Inc.').as('a')              .V().has('id','Alphabet Inc.|Mr. Sundar  Pichai').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'CEO & Director').property('fiscalYear', '2023').property('totalPay', '8802824').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Alphabet Inc.|Ms. Ruth M. Porat').fold().coalesce(unfold(),addV('Person').property('id','Alphabet Inc.|Ms. Ruth M. Porat').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1958').property('label', 'Person')
# edge query: "g.V().has('id','Alphabet Inc.').as('a')              .V().has('id','Alphabet Inc.|Ms. Ruth M. Porat').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'President, Chief Investment Officer, Senior VP & CFO').property('fiscalYear', '2023').property('totalPay', '2515700').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Alphabet Inc.|Dr. Lawrence Edward Page II').fold().coalesce(unfold(),addV('Person').property('id','Alphabet Inc.|Dr. Lawrence Edward Page II').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1973').property('label', 'Person')
# edge query: "g.V().has('id','Alphabet Inc.').as('a')              .V().has('id','Alphabet Inc.|Dr. Lawrence Edward Page II').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Co-Founder & Director').property('fiscalYear', '2023').property('totalPay', '1').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Alphabet Inc.|Mr. Sergey  Brin').fold().coalesce(unfold(),addV('Person').property('id','Alphabet Inc.|Mr. Sergey  Brin').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1974').property('label', 'Person')
# edge query: "g.V().has('id','Alphabet Inc.').as('a')              .V().has('id','Alphabet Inc.|Mr. Sergey  Brin').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Co-Founder & Director').property('fiscalYear', '2023').property('totalPay', '1').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Alphabet Inc.|Mr. J. Kent Walker').fold().coalesce(unfold(),addV('Person').property('id','Alphabet Inc.|Mr. J. Kent Walker').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1961').property('label', 'Person')
# edge query: "g.V().has('id','Alphabet Inc.').as('a')              .V().has('id','Alphabet Inc.|Mr. J. Kent Walker').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'President of Global Affairs, Chief Legal Officer & Company Secretary').property('fiscalYear', '2023').property('totalPay', '2511737').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Alphabet Inc.|Dr. Prabhakar  Raghavan').fold().coalesce(unfold(),addV('Person').property('id','Alphabet Inc.|Dr. Prabhakar  Raghavan').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1961').property('label', 'Person')
# edge query: "g.V().has('id','Alphabet Inc.').as('a')              .V().has('id','Alphabet Inc.|Dr. Prabhakar  Raghavan').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Senior Vice President of Knowledge and Information - Google').property('fiscalYear', '2023').property('totalPay', '2511737').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Alphabet Inc.|Mr. Philipp  Schindler').fold().coalesce(unfold(),addV('Person').property('id','Alphabet Inc.|Mr. Philipp  Schindler').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1971').property('label', 'Person')
# edge query: "g.V().has('id','Alphabet Inc.').as('a')              .V().has('id','Alphabet Inc.|Mr. Philipp  Schindler').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Senior Vice President & Chief Business Officer of Google').property('fiscalYear', '2023').property('totalPay', '2514032').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Alphabet Inc.|Ms. Amie Thuener OToole').fold().coalesce(unfold(),addV('Person').property('id','Alphabet Inc.|Ms. Amie Thuener OToole').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1975').property('label', 'Person')
# edge query: "g.V().has('id','Alphabet Inc.').as('a')              .V().has('id','Alphabet Inc.|Ms. Amie Thuener OToole').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chief Accounting Officer & VP').property('fiscalYear', '2023').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Alphabet Inc.|Ms. Ellen  West').fold().coalesce(unfold(),addV('Person').property('id','Alphabet Inc.|Ms. Ellen  West').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '0').property('label', 'Person')
# edge query: "g.V().has('id','Alphabet Inc.').as('a')              .V().has('id','Alphabet Inc.|Ms. Ellen  West').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Vice President of Investor Relations').property('fiscalYear', '2023').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Alphabet Inc.|Ms. Fiona Clare Cicconi').fold().coalesce(unfold(),addV('Person').property('id','Alphabet Inc.|Ms. Fiona Clare Cicconi').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1966').property('label', 'Person')
# edge query: "g.V().has('id','Alphabet Inc.').as('a')              .V().has('id','Alphabet Inc.|Ms. Fiona Clare Cicconi').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chief People Officer').property('fiscalYear', '2023').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# upserted [[{'id': 'd87cbf1f-1595-41af-ba14-6dd4430e02d7', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Alphabet Inc.|Mr. Sundar  Pichai', 'outV': 'Alphabet Inc.', 'properties': {'title': 'CEO & Director', 'fiscalYear': '2023', 'totalPay': '8802824', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': '600b9349-4daa-4171-8e76-2a13151e809e', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Alphabet Inc.|Ms. Ruth M. Porat', 'outV': 'Alphabet Inc.', 'properties': {'title': 'President, Chief Investment Officer, Senior VP & CFO', 'fiscalYear': '2023', 'totalPay': '2515700', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': '40e15383-d499-4980-af5d-647b798641f2', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Alphabet Inc.|Dr. Lawrence Edward Page II', 'outV': 'Alphabet Inc.', 'properties': {'title': 'Co-Founder & Director', 'fiscalYear': '2023', 'totalPay': '1', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': 'ded88647-ea55-4912-8a81-a73243072394', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Alphabet Inc.|Mr. Sergey  Brin', 'outV': 'Alphabet Inc.', 'properties': {'title': 'Co-Founder & Director', 'fiscalYear': '2023', 'totalPay': '1', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': '3821542c-ab2d-4cde-8cfa-1259496831f4', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Alphabet Inc.|Mr. J. Kent Walker', 'outV': 'Alphabet Inc.', 'properties': {'title': 'President of Global Affairs, Chief Legal Officer & Company Secretary', 'fiscalYear': '2023', 'totalPay': '2511737', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': 'b83809e9-7ead-435b-9196-ddde41fd0a30', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Alphabet Inc.|Dr. Prabhakar  Raghavan', 'outV': 'Alphabet Inc.', 'properties': {'title': 'Senior Vice President of Knowledge and Information - Google', 'fiscalYear': '2023', 'totalPay': '2511737', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': '8f9ba9d9-b517-4038-b12e-21e899b33a36', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Alphabet Inc.|Mr. Philipp  Schindler', 'outV': 'Alphabet Inc.', 'properties': {'title': 'Senior Vice President & Chief Business Officer of Google', 'fiscalYear': '2023', 'totalPay': '2514032', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': 'de22c044-d2c1-4f69-afff-3665531ea164', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Alphabet Inc.|Ms. Amie Thuener OToole', 'outV': 'Alphabet Inc.', 'properties': {'title': 'Chief Accounting Officer & VP', 'fiscalYear': '2023', 'totalPay': '0', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': '6bd7541e-c7be-4232-aecb-1c27b6d74ebc', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Alphabet Inc.|Ms. Ellen  West', 'outV': 'Alphabet Inc.', 'properties': {'title': 'Vice President of Investor Relations', 'fiscalYear': '2023', 'totalPay': '0', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': '69924d30-0d3d-4049-acf7-7227c05405b1', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Alphabet Inc.|Ms. Fiona Clare Cicconi', 'outV': 'Alphabet Inc.', 'properties': {'title': 'Chief People Officer', 'fiscalYear': '2023', 'totalPay': '0', 'excersicedValue': '0', 'unexcersicedValue': '0'}}]]
# upserting _test_assets\basic_info/META_1326801.json
# g.V().has('id','Meta Platforms, Inc.|Mr. Mark Elliot Zuckerberg').fold().coalesce(unfold(),addV('Person').property('id','Meta Platforms, Inc.|Mr. Mark Elliot Zuckerberg').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1984').property('label', 'Person')
# edge query: "g.V().has('id','Meta Platforms, Inc.').as('a')              .V().has('id','Meta Platforms, Inc.|Mr. Mark Elliot Zuckerberg').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Founder, Chairman & CEO').property('fiscalYear', '2023').property('totalPay', '24399968').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Meta Platforms, Inc.|Ms. Susan J. S. Li').fold().coalesce(unfold(),addV('Person').property('id','Meta Platforms, Inc.|Ms. Susan J. S. Li').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1986').property('label', 'Person')
# edge query: "g.V().has('id','Meta Platforms, Inc.').as('a')              .V().has('id','Meta Platforms, Inc.|Ms. Susan J. S. Li').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chief Financial Officer').property('fiscalYear', '2023').property('totalPay', '1963161').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Meta Platforms, Inc.|Mr. Javier  Olivan').fold().coalesce(unfold(),addV('Person').property('id','Meta Platforms, Inc.|Mr. Javier  Olivan').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1977').property('label', 'Person')
# edge query: "g.V().has('id','Meta Platforms, Inc.').as('a')              .V().has('id','Meta Platforms, Inc.|Mr. Javier  Olivan').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chief Operating Officer').property('fiscalYear', '2023').property('totalPay', '4065442').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Meta Platforms, Inc.|Mr. Andrew  Bosworth').fold().coalesce(unfold(),addV('Person').property('id','Meta Platforms, Inc.|Mr. Andrew  Bosworth').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1982').property('label', 'Person')
# edge query: "g.V().has('id','Meta Platforms, Inc.').as('a')              .V().has('id','Meta Platforms, Inc.|Mr. Andrew  Bosworth').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chief Technology Officer').property('fiscalYear', '2023').property('totalPay', '2000988').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Meta Platforms, Inc.|Mr. Christopher K. Cox').fold().coalesce(unfold(),addV('Person').property('id','Meta Platforms, Inc.|Mr. Christopher K. Cox').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1983').property('label', 'Person')
# edge query: "g.V().has('id','Meta Platforms, Inc.').as('a')              .V().has('id','Meta Platforms, Inc.|Mr. Christopher K. Cox').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chief Product Officer').property('fiscalYear', '2023').property('totalPay', '2013913').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Meta Platforms, Inc.|Mr. Aaron A. Anderson').fold().coalesce(unfold(),addV('Person').property('id','Meta Platforms, Inc.|Mr. Aaron A. Anderson').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '0').property('label', 'Person')
# edge query: "g.V().has('id','Meta Platforms, Inc.').as('a')              .V().has('id','Meta Platforms, Inc.|Mr. Aaron A. Anderson').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chief Accounting Officer').property('fiscalYear', '2023').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Meta Platforms, Inc.|Mr. Atish  Banerjea').fold().coalesce(unfold(),addV('Person').property('id','Meta Platforms, Inc.|Mr. Atish  Banerjea').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1966').property('label', 'Person')
# edge query: "g.V().has('id','Meta Platforms, Inc.').as('a')              .V().has('id','Meta Platforms, Inc.|Mr. Atish  Banerjea').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chief Information Officer').property('fiscalYear', '2023').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Meta Platforms, Inc.|Ms. Deborah T. Crawford').fold().coalesce(unfold(),addV('Person').property('id','Meta Platforms, Inc.|Ms. Deborah T. Crawford').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '0').property('label', 'Person')
# edge query: "g.V().has('id','Meta Platforms, Inc.').as('a')              .V().has('id','Meta Platforms, Inc.|Ms. Deborah T. Crawford').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Vice President of Investor Relations').property('fiscalYear', '2023').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Meta Platforms, Inc.|Ms. Jennifer G. Newstead').fold().coalesce(unfold(),addV('Person').property('id','Meta Platforms, Inc.|Ms. Jennifer G. Newstead').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1970').property('label', 'Person')
# edge query: "g.V().has('id','Meta Platforms, Inc.').as('a')              .V().has('id','Meta Platforms, Inc.|Ms. Jennifer G. Newstead').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chief Legal Officer').property('fiscalYear', '2023').property('totalPay', '3079624').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Meta Platforms, Inc.|Mr. Henry T. A. Moniz').fold().coalesce(unfold(),addV('Person').property('id','Meta Platforms, Inc.|Mr. Henry T. A. Moniz').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1965').property('label', 'Person')
# edge query: "g.V().has('id','Meta Platforms, Inc.').as('a')              .V().has('id','Meta Platforms, Inc.|Mr. Henry T. A. Moniz').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chief Compliance Officer').property('fiscalYear', '2023').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# upserted [[{'id': '6acc630e-2d16-4b20-8456-5e79aa1fdb25', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Meta Platforms, Inc.|Mr. Mark Elliot Zuckerberg', 'outV': 'Meta Platforms, Inc.', 'properties': {'title': 'Founder, Chairman & CEO', 'fiscalYear': '2023', 'totalPay': '24399968', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': 'a3393dc9-cde9-429f-bc7c-46d135ddd0f0', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Meta Platforms, Inc.|Ms. Susan J. S. Li', 'outV': 'Meta Platforms, Inc.', 'properties': {'title': 'Chief Financial Officer', 'fiscalYear': '2023', 'totalPay': '1963161', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': '0090cb4f-39bd-42d3-bdd4-7082a1d50900', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Meta Platforms, Inc.|Mr. Javier  Olivan', 'outV': 'Meta Platforms, Inc.', 'properties': {'title': 'Chief Operating Officer', 'fiscalYear': '2023', 'totalPay': '4065442', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': 'bf133fea-bee7-4d08-989e-02f546456d18', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Meta Platforms, Inc.|Mr. Andrew  Bosworth', 'outV': 'Meta Platforms, Inc.', 'properties': {'title': 'Chief Technology Officer', 'fiscalYear': '2023', 'totalPay': '2000988', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': '8c5c491d-fc05-47e7-8b42-0556365e292c', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Meta Platforms, Inc.|Mr. Christopher K. Cox', 'outV': 'Meta Platforms, Inc.', 'properties': {'title': 'Chief Product Officer', 'fiscalYear': '2023', 'totalPay': '2013913', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': 'c8dc4f9a-632e-4baf-873b-4710a806d064', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Meta Platforms, Inc.|Mr. Aaron A. Anderson', 'outV': 'Meta Platforms, Inc.', 'properties': {'title': 'Chief Accounting Officer', 'fiscalYear': '2023', 'totalPay': '0', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': 'd8bc5919-6687-4bfe-8484-46237b6d1468', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Meta Platforms, Inc.|Mr. Atish  Banerjea', 'outV': 'Meta Platforms, Inc.', 'properties': {'title': 'Chief Information Officer', 'fiscalYear': '2023', 'totalPay': '0', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': 'cb747621-187a-4d24-b302-5b534f3c02ff', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Meta Platforms, Inc.|Ms. Deborah T. Crawford', 'outV': 'Meta Platforms, Inc.', 'properties': {'title': 'Vice President of Investor Relations', 'fiscalYear': '2023', 'totalPay': '0', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': '97f843b6-6100-49d4-8869-a189f3a1f87a', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Meta Platforms, Inc.|Ms. Jennifer G. Newstead', 'outV': 'Meta Platforms, Inc.', 'properties': {'title': 'Chief Legal Officer', 'fiscalYear': '2023', 'totalPay': '3079624', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': '4e863738-c142-4afe-b90d-63fa900bf12b', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Meta Platforms, Inc.|Mr. Henry T. A. Moniz', 'outV': 'Meta Platforms, Inc.', 'properties': {'title': 'Chief Compliance Officer', 'fiscalYear': '2023', 'totalPay': '0', 'excersicedValue': '0', 'unexcersicedValue': '0'}}]]
# upserting _test_assets\basic_info/NFLX_1065280.json
# g.V().has('id','NETFLIX INC|Mr. Wilmot Reed Hastings Jr.').fold().coalesce(unfold(),addV('Person').property('id','NETFLIX INC|Mr. Wilmot Reed Hastings Jr.').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1960').property('label', 'Person')
# edge query: "g.V().has('id','NETFLIX INC').as('a')              .V().has('id','NETFLIX INC|Mr. Wilmot Reed Hastings Jr.').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Co-Founder & Executive Chairman').property('fiscalYear', '2023').property('totalPay', '647054').property('excersicedValue', '84432176').property('unexcersicedValue', '679795584')
# g.V().has('id','NETFLIX INC|Mr. Theodore A. Sarandos').fold().coalesce(unfold(),addV('Person').property('id','NETFLIX INC|Mr. Theodore A. Sarandos').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1965').property('label', 'Person')
# edge query: "g.V().has('id','NETFLIX INC').as('a')              .V().has('id','NETFLIX INC|Mr. Theodore A. Sarandos').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Co-CEO, President & Director').property('fiscalYear', '2023').property('totalPay', '21526316').property('excersicedValue', '15418673').property('unexcersicedValue', '154477888')
# g.V().has('id','NETFLIX INC|Mr. Gregory K. Peters').fold().coalesce(unfold(),addV('Person').property('id','NETFLIX INC|Mr. Gregory K. Peters').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1971').property('label', 'Person')
# edge query: "g.V().has('id','NETFLIX INC').as('a')              .V().has('id','NETFLIX INC|Mr. Gregory K. Peters').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Co-CEO, President & Director').property('fiscalYear', '2023').property('totalPay', '17449536').property('excersicedValue', '2932705').property('unexcersicedValue', '64158196')
# g.V().has('id','NETFLIX INC|Mr. Spencer Adam Neumann').fold().coalesce(unfold(),addV('Person').property('id','NETFLIX INC|Mr. Spencer Adam Neumann').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1970').property('label', 'Person')
# edge query: "g.V().has('id','NETFLIX INC').as('a')              .V().has('id','NETFLIX INC|Mr. Spencer Adam Neumann').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chief Financial Officer').property('fiscalYear', '2023').property('totalPay', '7094073').property('excersicedValue', '0').property('unexcersicedValue', '26783668')
# g.V().has('id','NETFLIX INC|Mr. David  Hyman').fold().coalesce(unfold(),addV('Person').property('id','NETFLIX INC|Mr. David  Hyman').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1966').property('label', 'Person')
# edge query: "g.V().has('id','NETFLIX INC').as('a')              .V().has('id','NETFLIX INC|Mr. David  Hyman').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chief Legal Officer & Secretary').property('fiscalYear', '2023').property('totalPay', '4016044').property('excersicedValue', '7839044').property('unexcersicedValue', '50648104')
# g.V().has('id','NETFLIX INC|Ms. Rachel  Whetstone').fold().coalesce(unfold(),addV('Person').property('id','NETFLIX INC|Ms. Rachel  Whetstone').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1968').property('label', 'Person')
# edge query: "g.V().has('id','NETFLIX INC').as('a')              .V().has('id','NETFLIX INC|Ms. Rachel  Whetstone').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chief Communications Officer').property('fiscalYear', '2023').property('totalPay', '5700000').property('excersicedValue', '0').property('unexcersicedValue', '3240559')
# g.V().has('id','NETFLIX INC|Mr. Meabe Sergio Ezama').fold().coalesce(unfold(),addV('Person').property('id','NETFLIX INC|Mr. Meabe Sergio Ezama').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1972').property('label', 'Person')
# edge query: "g.V().has('id','NETFLIX INC').as('a')              .V().has('id','NETFLIX INC|Mr. Meabe Sergio Ezama').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chief Talent Officer').property('fiscalYear', '2023').property('totalPay', '3873554').property('excersicedValue', '3018513').property('unexcersicedValue', '321909')
# g.V().has('id','NETFLIX INC|Mr. Jeffrey William Karbowski').fold().coalesce(unfold(),addV('Person').property('id','NETFLIX INC|Mr. Jeffrey William Karbowski').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1979').property('label', 'Person')
# edge query: "g.V().has('id','NETFLIX INC').as('a')              .V().has('id','NETFLIX INC|Mr. Jeffrey William Karbowski').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chief Accounting Officer & Principal Accounting Officer').property('fiscalYear', '2023').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','NETFLIX INC|Ms. Elizabeth  Stone').fold().coalesce(unfold(),addV('Person').property('id','NETFLIX INC|Ms. Elizabeth  Stone').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '0').property('label', 'Person')
# edge query: "g.V().has('id','NETFLIX INC').as('a')              .V().has('id','NETFLIX INC|Ms. Elizabeth  Stone').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chief Technology Officer').property('fiscalYear', '2023').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','NETFLIX INC|Mr. Spencer  Wang').fold().coalesce(unfold(),addV('Person').property('id','NETFLIX INC|Mr. Spencer  Wang').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '0').property('label', 'Person')
# edge query: "g.V().has('id','NETFLIX INC').as('a')              .V().has('id','NETFLIX INC|Mr. Spencer  Wang').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Vice President of Finance, Corporate Development & Investor Relations').property('fiscalYear', '2023').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# upserted [[{'id': '9e40d6e0-ba19-4fac-885d-4656c2e0332d', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'NETFLIX INC|Mr. Wilmot Reed Hastings Jr.', 'outV': 'NETFLIX INC', 'properties': {'title': 'Co-Founder & Executive Chairman', 'fiscalYear': '2023', 'totalPay': '647054', 'excersicedValue': '84432176', 'unexcersicedValue': '679795584'}}], [{'id': '9ae7b864-3d59-4318-acf6-f6f0a63c9fdb', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'NETFLIX INC|Mr. Theodore A. Sarandos', 'outV': 'NETFLIX INC', 'properties': {'title': 'Co-CEO, President & Director', 'fiscalYear': '2023', 'totalPay': '21526316', 'excersicedValue': '15418673', 'unexcersicedValue': '154477888'}}], [{'id': '2cdb7aba-1cc3-4e35-9f92-7d7a35a310c4', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'NETFLIX INC|Mr. Gregory K. Peters', 'outV': 'NETFLIX INC', 'properties': {'title': 'Co-CEO, President & Director', 'fiscalYear': '2023', 'totalPay': '17449536', 'excersicedValue': '2932705', 'unexcersicedValue': '64158196'}}], [{'id': '87f7d16c-3602-4ed8-9d41-2bfabfbaf2f6', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'NETFLIX INC|Mr. Spencer Adam Neumann', 'outV': 'NETFLIX INC', 'properties': {'title': 'Chief Financial Officer', 'fiscalYear': '2023', 'totalPay': '7094073', 'excersicedValue': '0', 'unexcersicedValue': '26783668'}}], [{'id': '95abffbc-173d-40c6-9f4a-55a6a18b93dd', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'NETFLIX INC|Mr. David  Hyman', 'outV': 'NETFLIX INC', 'properties': {'title': 'Chief Legal Officer & Secretary', 'fiscalYear': '2023', 'totalPay': '4016044', 'excersicedValue': '7839044', 'unexcersicedValue': '50648104'}}], [{'id': 'a0883622-5917-4cc0-a8b4-450599ebbe27', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'NETFLIX INC|Ms. Rachel  Whetstone', 'outV': 'NETFLIX INC', 'properties': {'title': 'Chief Communications Officer', 'fiscalYear': '2023', 'totalPay': '5700000', 'excersicedValue': '0', 'unexcersicedValue': '3240559'}}], [{'id': 'ab6546be-6aad-4cdb-980a-b2ed13204771', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'NETFLIX INC|Mr. Meabe Sergio Ezama', 'outV': 'NETFLIX INC', 'properties': {'title': 'Chief Talent Officer', 'fiscalYear': '2023', 'totalPay': '3873554', 'excersicedValue': '3018513', 'unexcersicedValue': '321909'}}], [{'id': 'adb3e64f-6938-4671-81d1-fdcc348e8eb3', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'NETFLIX INC|Mr. Jeffrey William Karbowski', 'outV': 'NETFLIX INC', 'properties': {'title': 'Chief Accounting Officer & Principal Accounting Officer', 'fiscalYear': '2023', 'totalPay': '0', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': '47c1d1e1-e7b6-4384-a343-58492cae4de9', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'NETFLIX INC|Ms. Elizabeth  Stone', 'outV': 'NETFLIX INC', 'properties': {'title': 'Chief Technology Officer', 'fiscalYear': '2023', 'totalPay': '0', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': '876dbb24-c75b-40a8-a533-116b88f379b9', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'NETFLIX INC|Mr. Spencer  Wang', 'outV': 'NETFLIX INC', 'properties': {'title': 'Vice President of Finance, Corporate Development & Investor Relations', 'fiscalYear': '2023', 'totalPay': '0', 'excersicedValue': '0', 'unexcersicedValue': '0'}}]]
# upserting _test_assets\basic_info/TMUS_1283699.json
# g.V().has('id','T-Mobile US, Inc.|Mr. G. Michael Sievert').fold().coalesce(unfold(),addV('Person').property('id','T-Mobile US, Inc.|Mr. G. Michael Sievert').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1970').property('label', 'Person')
# edge query: "g.V().has('id','T-Mobile US, Inc.').as('a')              .V().has('id','T-Mobile US, Inc.|Mr. G. Michael Sievert').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'President, CEO & Director').property('fiscalYear', '2023').property('totalPay', '8207045').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','T-Mobile US, Inc.|Mr. Peter  Osvaldik').fold().coalesce(unfold(),addV('Person').property('id','T-Mobile US, Inc.|Mr. Peter  Osvaldik').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1977').property('label', 'Person')
# edge query: "g.V().has('id','T-Mobile US, Inc.').as('a')              .V().has('id','T-Mobile US, Inc.|Mr. Peter  Osvaldik').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Executive VP & CFO').property('fiscalYear', '2023').property('totalPay', '3529150').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','T-Mobile US, Inc.|Mr. Mark W. Nelson').fold().coalesce(unfold(),addV('Person').property('id','T-Mobile US, Inc.|Mr. Mark W. Nelson').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1968').property('label', 'Person')
# edge query: "g.V().has('id','T-Mobile US, Inc.').as('a')              .V().has('id','T-Mobile US, Inc.|Mr. Mark W. Nelson').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Executive VP & General Counsel').property('fiscalYear', '2023').property('totalPay', '3530065').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','T-Mobile US, Inc.|Mr. Michael J. Katz').fold().coalesce(unfold(),addV('Person').property('id','T-Mobile US, Inc.|Mr. Michael J. Katz').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1979').property('label', 'Person')
# edge query: "g.V().has('id','T-Mobile US, Inc.').as('a')              .V().has('id','T-Mobile US, Inc.|Mr. Michael J. Katz').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'President of Marketing, Strategy & Products').property('fiscalYear', '2023').property('totalPay', '2565200').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','T-Mobile US, Inc.|Mr. Jonathan A. Freier').fold().coalesce(unfold(),addV('Person').property('id','T-Mobile US, Inc.|Mr. Jonathan A. Freier').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1976').property('label', 'Person')
# edge query: "g.V().has('id','T-Mobile US, Inc.').as('a')              .V().has('id','T-Mobile US, Inc.|Mr. Jonathan A. Freier').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'President of Consumer Group').property('fiscalYear', '2023').property('totalPay', '2542606').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','T-Mobile US, Inc.|Ms. Callie R. Field').fold().coalesce(unfold(),addV('Person').property('id','T-Mobile US, Inc.|Ms. Callie R. Field').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1979').property('label', 'Person')
# edge query: "g.V().has('id','T-Mobile US, Inc.').as('a')              .V().has('id','T-Mobile US, Inc.|Ms. Callie R. Field').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'President of T-Mobile Business Group').property('fiscalYear', '2023').property('totalPay', '2533300').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','T-Mobile US, Inc.|Ms. Dara A. Bazzano').fold().coalesce(unfold(),addV('Person').property('id','T-Mobile US, Inc.|Ms. Dara A. Bazzano').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1969').property('label', 'Person')
# edge query: "g.V().has('id','T-Mobile US, Inc.').as('a')              .V().has('id','T-Mobile US, Inc.|Ms. Dara A. Bazzano').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Senior VP of Finance & Chief Accounting Officer').property('fiscalYear', '2023').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','T-Mobile US, Inc.|Mr. John  Saw Ph.D.').fold().coalesce(unfold(),addV('Person').property('id','T-Mobile US, Inc.|Mr. John  Saw Ph.D.').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '0').property('label', 'Person')
# edge query: "g.V().has('id','T-Mobile US, Inc.').as('a')              .V().has('id','T-Mobile US, Inc.|Mr. John  Saw Ph.D.').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Executive VP & CTO').property('fiscalYear', '2023').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','T-Mobile US, Inc.|Mr. Jud  Henry').fold().coalesce(unfold(),addV('Person').property('id','T-Mobile US, Inc.|Mr. Jud  Henry').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '0').property('label', 'Person')
# edge query: "g.V().has('id','T-Mobile US, Inc.').as('a')              .V().has('id','T-Mobile US, Inc.|Mr. Jud  Henry').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Senior Vice President of Investor Relations').property('fiscalYear', '2023').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','T-Mobile US, Inc.|Ms. Janice V. Kapner').fold().coalesce(unfold(),addV('Person').property('id','T-Mobile US, Inc.|Ms. Janice V. Kapner').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '0').property('label', 'Person')
# edge query: "g.V().has('id','T-Mobile US, Inc.').as('a')              .V().has('id','T-Mobile US, Inc.|Ms. Janice V. Kapner').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Executive VP and Chief Communications & Corporate Responsibility Officer').property('fiscalYear', '2023').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# ...
# upserting _test_assets\basic_info/MGOM_1697412.json
# g.V().has('id','Migom Global Corp|Mr. Georgi  Parrik').fold().coalesce(unfold(),addV('Person').property('id','Migom Global Corp|Mr. Georgi  Parrik').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Financial Services').property('sector', 'Financial Services').property('yearBorn', '1980').property('label', 'Person')
# edge query: "g.V().has('id','Migom Global Corp').as('a')              .V().has('id','Migom Global Corp|Mr. Georgi  Parrik').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chairman & CEO').property('fiscalYear', '2021').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Migom Global Corp|Mr. Thomas A. Schaetti').fold().coalesce(unfold(),addV('Person').property('id','Migom Global Corp|Mr. Thomas A. Schaetti').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Financial Services').property('sector', 'Financial Services').property('yearBorn', '1976').property('label', 'Person')
# edge query: "g.V().has('id','Migom Global Corp').as('a')              .V().has('id','Migom Global Corp|Mr. Thomas A. Schaetti').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'President & Director').property('fiscalYear', '2021').property('totalPay', '200000').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Migom Global Corp|Mr. Stefan  Lenhart').fold().coalesce(unfold(),addV('Person').property('id','Migom Global Corp|Mr. Stefan  Lenhart').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Financial Services').property('sector', 'Financial Services').property('yearBorn', '1979').property('label', 'Person')
# edge query: "g.V().has('id','Migom Global Corp').as('a')              .V().has('id','Migom Global Corp|Mr. Stefan  Lenhart').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Treasurer & Director').property('fiscalYear', '2021').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Migom Global Corp|Mr. Ricardo Salcedo Sanchez').fold().coalesce(unfold(),addV('Person').property('id','Migom Global Corp|Mr. Ricardo Salcedo Sanchez').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Financial Services').property('sector', 'Financial Services').property('yearBorn', '1985').property('label', 'Person')
# edge query: "g.V().has('id','Migom Global Corp').as('a')              .V().has('id','Migom Global Corp|Mr. Ricardo Salcedo Sanchez').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'CFO & Secretary').property('fiscalYear', '2021').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# upserted [[{'id': '9961dacd-61c1-491e-be29-c239ef8d3ed8', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Migom Global Corp|Mr. Georgi  Parrik', 'outV': 'Migom Global Corp', 'properties': {'title': 'Chairman & CEO', 'fiscalYear': '2021', 'totalPay': '0', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': 'd985dad0-0e9d-4b80-9071-56b7efdb13b8', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Migom Global Corp|Mr. Thomas A. Schaetti', 'outV': 'Migom Global Corp', 'properties': {'title': 'President & Director', 'fiscalYear': '2021', 'totalPay': '200000', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': 'c21bdff6-cc75-4f94-a036-c9ba8387dd92', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Migom Global Corp|Mr. Stefan  Lenhart', 'outV': 'Migom Global Corp', 'properties': {'title': 'Treasurer & Director', 'fiscalYear': '2021', 'totalPay': '0', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': 'e96b7709-3560-46ad-89ac-c0f15f6ae392', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Migom Global Corp|Mr. Ricardo Salcedo Sanchez', 'outV': 'Migom Global Corp', 'properties': {'title': 'CFO & Secretary', 'fiscalYear': '2021', 'totalPay': '0', 'excersicedValue': '0', 'unexcersicedValue': '0'}}]]
# upserting _test_assets\basic_info/EMMS_783005.json
# g.V().has('id','Emmis Corp|Mr. Jeffrey H. Smulyan').fold().coalesce(unfold(),addV('Person').property('id','Emmis Corp|Mr. Jeffrey H. Smulyan').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1947').property('label', 'Person')
# edge query: "g.V().has('id','Emmis Corp').as('a')              .V().has('id','Emmis Corp|Mr. Jeffrey H. Smulyan').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chairman, CEO & Founder').property('fiscalYear', '2020').property('totalPay', '3716943').property('excersicedValue', '0').property('unexcersicedValue', '30235')
# g.V().has('id','Emmis Corp|Mr. Patrick M. Walsh').fold().coalesce(unfold(),addV('Person').property('id','Emmis Corp|Mr. Patrick M. Walsh').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1967').property('label', 'Person')
# edge query: "g.V().has('id','Emmis Corp').as('a')              .V().has('id','Emmis Corp|Mr. Patrick M. Walsh').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'President, COO & Director').property('fiscalYear', '2020').property('totalPay', '1934710').property('excersicedValue', '0').property('unexcersicedValue', '39424')
# g.V().has('id','Emmis Corp|Mr. Ryan A. Hornaday').fold().coalesce(unfold(),addV('Person').property('id','Emmis Corp|Mr. Ryan A. Hornaday').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1974').property('label', 'Person')
# edge query: "g.V().has('id','Emmis Corp').as('a')              .V().has('id','Emmis Corp|Mr. Ryan A. Hornaday').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Executive VP, CFO & Treasurer').property('fiscalYear', '2020').property('totalPay', '1090037').property('excersicedValue', '0').property('unexcersicedValue', '12904')
# g.V().has('id','Emmis Corp|Ms. Kate Healey Snedeker APR').fold().coalesce(unfold(),addV('Person').property('id','Emmis Corp|Ms. Kate Healey Snedeker APR').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '0').property('label', 'Person')
# edge query: "g.V().has('id','Emmis Corp').as('a')              .V().has('id','Emmis Corp|Ms. Kate Healey Snedeker APR').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Media & Investor Relations Contact').property('fiscalYear', '2020').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Emmis Corp|Mr. J. Scott Enright Esq.').fold().coalesce(unfold(),addV('Person').property('id','Emmis Corp|Mr. J. Scott Enright Esq.').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1963').property('label', 'Person')
# edge query: "g.V().has('id','Emmis Corp').as('a')              .V().has('id','Emmis Corp|Mr. J. Scott Enright Esq.').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Executive VP, General Counsel & Secretary').property('fiscalYear', '2020').property('totalPay', '467344').property('excersicedValue', '0').property('unexcersicedValue', '126874')
# g.V().has('id','Emmis Corp|Mr. Traci L. Thomson').fold().coalesce(unfold(),addV('Person').property('id','Emmis Corp|Mr. Traci L. Thomson').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '0').property('label', 'Person')
# edge query: "g.V().has('id','Emmis Corp').as('a')              .V().has('id','Emmis Corp|Mr. Traci L. Thomson').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Senior Vice President of Human Resources').property('fiscalYear', '2020').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# g.V().has('id','Emmis Corp|Mr. Gregory T. Loewen').fold().coalesce(unfold(),addV('Person').property('id','Emmis Corp|Mr. Gregory T. Loewen').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1972').property('label', 'Person')
# edge query: "g.V().has('id','Emmis Corp').as('a')              .V().has('id','Emmis Corp|Mr. Gregory T. Loewen').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chief Executive Officer of Digonex').property('fiscalYear', '2020').property('totalPay', '677729').property('excersicedValue', '73131').property('unexcersicedValue', '0')
# g.V().has('id','Emmis Corp|Mr. Thomas J. Rupe').fold().coalesce(unfold(),addV('Person').property('id','Emmis Corp|Mr. Thomas J. Rupe').property('type','Person').property('partitionKeyType', 'sector').property('partitionKey', 'Communication Services').property('sector', 'Communication Services').property('yearBorn', '1983').property('label', 'Person')
# edge query: "g.V().has('id','Emmis Corp').as('a')              .V().has('id','Emmis Corp|Mr. Thomas J. Rupe').as('b')             .choose(                __.inE('HAS_OFFICER').where(outV().as('a')),                __.identity(),                __.addE('HAS_OFFICER').from('a').to('b')            )                    .property('title', 'Chief Executive Officer of Lencore').property('fiscalYear', '2020').property('totalPay', '0').property('excersicedValue', '0').property('unexcersicedValue', '0')
# upserted [[{'id': '38f4c99c-5b75-44d5-97ce-806d0353c1d1', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Emmis Corp|Mr. Jeffrey H. Smulyan', 'outV': 'Emmis Corp', 'properties': {'title': 'Chairman, CEO & Founder', 'fiscalYear': '2020', 'totalPay': '3716943', 'excersicedValue': '0', 'unexcersicedValue': '30235'}}], [{'id': '114f3220-d055-4cef-a33d-790db6917693', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Emmis Corp|Mr. Patrick M. Walsh', 'outV': 'Emmis Corp', 'properties': {'title': 'President, COO & Director', 'fiscalYear': '2020', 'totalPay': '1934710', 'excersicedValue': '0', 'unexcersicedValue': '39424'}}], [{'id': 'cf5a7949-3464-4f55-8c18-5c3928930419', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Emmis Corp|Mr. Ryan A. Hornaday', 'outV': 'Emmis Corp', 'properties': {'title': 'Executive VP, CFO & Treasurer', 'fiscalYear': '2020', 'totalPay': '1090037', 'excersicedValue': '0', 'unexcersicedValue': '12904'}}], [{'id': '660ffb28-33b7-48c8-8512-7603a8ff2f77', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Emmis Corp|Ms. Kate Healey Snedeker APR', 'outV': 'Emmis Corp', 'properties': {'title': 'Media & Investor Relations Contact', 'fiscalYear': '2020', 'totalPay': '0', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': '4ff93361-58bb-4840-ad16-25b26fef4d64', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Emmis Corp|Mr. J. Scott Enright Esq.', 'outV': 'Emmis Corp', 'properties': {'title': 'Executive VP, General Counsel & Secretary', 'fiscalYear': '2020', 'totalPay': '467344', 'excersicedValue': '0', 'unexcersicedValue': '126874'}}], [{'id': 'eb7e3c01-46a7-4971-bf37-e5a97a885b42', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Emmis Corp|Mr. Traci L. Thomson', 'outV': 'Emmis Corp', 'properties': {'title': 'Senior Vice President of Human Resources', 'fiscalYear': '2020', 'totalPay': '0', 'excersicedValue': '0', 'unexcersicedValue': '0'}}], [{'id': '3feb98e4-3608-4beb-ba00-32be72390dc5', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Emmis Corp|Mr. Gregory T. Loewen', 'outV': 'Emmis Corp', 'properties': {'title': 'Chief Executive Officer of Digonex', 'fiscalYear': '2020', 'totalPay': '677729', 'excersicedValue': '73131', 'unexcersicedValue': '0'}}], [{'id': 'fadf5174-bf53-4155-b021-d518a0af0dc3', 'label': 'HAS_OFFICER', 'type': 'edge', 'inVLabel': 'Person', 'outVLabel': 'Company', 'inV': 'Emmis Corp|Mr. Thomas J. Rupe', 'outV': 'Emmis Corp', 'properties': {'title': 'Chief Executive Officer of Lencore', 'fiscalYear': '2020', 'totalPay': '0', 'excersicedValue': '0', 'unexcersicedValue': '0'}}]]

# %%
from glob import glob
import json
import nest_asyncio
nest_asyncio.apply()

# Add Form-10k Information
# form13_data = pd.read_csv("_test_assets\\sector_communication\\13F_HR_extracted.csv")
# form10k_data_path = "_test_assets\\sector_communication\\10k-clean"

def upsert_10k(input_directory: str):
    graphClient = CosmosDBGraphStore(connection=graphDbConnection)
    for file_json in glob(f"{input_directory}/*"):
        file_content = json.load(open(file_json))
        cik = file_content['cik']
        company_name = file_content['name']
        primaryExchange = file_content['primaryExchange']
        date = file_content['date']
        cusips = file_content['cusips']
        sequence_number = file_content['accession']
        clean_name = company_name.replace("/", "").replace("\\", "").replace("'", "")
        # edgar files are formated {cik}-{yy}-{sequence}.txt
        accession = f"{cik}-{date[2:4]}-{sequence_number}"
        graphClient.upsert_node(Node(
            id=clean_name,
            type="SEC Form",
            properties={
                "filingDate": date,
                "accession": accession,
                "primaryExchange": primaryExchange,
                "partitionKeyValueType": "cik",
                "partitionKey": cik,
                "names": clean_name
            }
        ))
